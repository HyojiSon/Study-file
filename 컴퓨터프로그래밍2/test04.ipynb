# %%
# !apt-get update -qq
# !apt-get install fonts-nanum* -qq

# %%
from google.colab import files

uploaded = files.upload()
# Out:
#      <input type="file" id="files-af98b662-0253-40f6-902c-7a457ed0d4f9" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-af98b662-0253-40f6-902c-7a457ed0d4f9">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving pop.csv to pop (1).csv

# %%
import pandas as pd

df=pd.read_csv('pop.csv',encoding = '949')
print(df)
# Out:
#        시군구별   2011.07   2020.07
# 0        전국  50641565  51839852
# 1     서울특별시  10282472   9715429
# 2     부산광역시   3560813   3402776
# 3     대구광역시   2509833   2428022
# 4     인천광역시   2782458   2945565
# 5     광주광역시   1461368   1454709
# 6     대전광역시   1510468   1470225
# 7     울산광역시   1131325   1141362
# 8   세종특별자치시         0    346217
# 9       경기도  11874213  13351891
# 10      강원도   1532825   1540094
# 11     충청북도   1556984   1597936
# 12     충청남도   2090270   2120692
# 13     전라북도   1871388   1808044
# 14     전라남도   1913185   1853339
# 15     경상북도   2691181   2644001
# 16     경상남도   3298607   3347637
# 17  제주특별자치도    574175    671913

# %%
import matplotlib.font_manager as fm
fm._rebuild()

# %%
import matplotlib.pyplot as plt
plt.rc('font',family='NanumGothic')

# %%
labels= df['시군구별']
ratio = df['2011.07']

plt.pie(ratio, labels=labels)
plt.show()

# %%
labels= df.loc[1:,'시군구별']
ratio = df.loc[1:,'2011.07']

plt.pie(ratio, labels=labels)
plt.show()
